# %% [markdown]
# # Neural Surrogate RL Training - GPU Accelerated
#
# Train per-topology RL agents using Colab T4 GPU.
#
# **Steps:**
# 1. Runtime > Change runtime type > T4 GPU
# 2. Run all cells
# 3. Upload multi_topology_surrogate.pt when prompted
# 4. Download agents.zip when done

# %%
# !git clone https://github.com/tusharpathaknyu/neural-surrogate-rl-circuits.git
# %cd neural-surrogate-rl-circuits
# !pip install torch numpy matplotlib tqdm

# %%
import torch
print(f'CUDA available: {torch.cuda.is_available()}')
if torch.cuda.is_available():
    print(f'GPU: {torch.cuda.get_device_name(0)}')
    print(f'Memory: {torch.cuda.get_device_properties(0).total_memory / 1e9:.1f} GB')

# %%
from google.colab import files
import os
os.makedirs('checkpoints', exist_ok=True)
print('Upload multi_topology_surrogate.pt:')
uploaded = files.upload()
for f in uploaded:
    if 'surrogate' in f:
        os.rename(f, f'checkpoints/{f}')
        print(f'Moved to checkpoints/')

# %%
# !python rl/train_per_topology_agents.py

# %%
import shutil
from google.colab import files
shutil.make_archive('agents', 'zip', 'checkpoints')
print('Downloading agents.zip...')
files.download('agents.zip')
